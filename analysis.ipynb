# %% [markdown]
# <a href="https://colab.research.google.com/github/ouiamouatat26-gif/data-analysis-project/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

print("Hello, this is my first data analysis project")
# Out:
# Hello, this is my first data analysis project
